# %%
import pandas as pd 

import numpy as np

import scipy.stats as s 

import matplotlib.pyplot as plt

import seaborn as sns

# %%
data = pd.read_csv("mushrooms.csv")

# %%
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
data.shape[0]
# Out:
# 8124

# %%
training_data_len = int(0.7*data.shape[0])

# %%
training_data_len
# Out:
# 5686

# %%
cv_data_len = int(0.2*data.shape[0])

# %%
cv_data_len
# Out:
# 1624

# %%
testing_data_len = int(0.1*data.shape[0])

# %%
testing_data_len
# Out:
# 812

# %%
poissonous_train = data[data['class'] == 'p'].iloc[0:training_data_len//2]

non_poissonous_train = data[data['class'] == 'e'].iloc[0:training_data_len//2]

# %%
training_data = pd.concat([poissonous_train,non_poissonous_train])

# %%
training_data.shape
# Out:
# (5686, 23)

# %%
poissonous_remain = data[data['class'] == 'p'].iloc[training_data_len//2:]

non_poissonous_remain = data[data['class'] == 'e'].iloc[training_data_len//2:]

# %%
remaining_data = pd.concat([poissonous_remain,non_poissonous_remain])

# %%
remaining_data.shape
# Out:
# (2438, 23)

# %%
remaining_data
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 6547     p         f           y         e       f    f               f
# 6548     p         f           y         e       f    s               f
# 6549     p         x           y         e       f    s               f
# 6550     p         k           s         e       f    f               f
# 6551     p         f           y         e       f    s               f
# 6552     p         f           y         n       f    y               f
# 6553     p         f           s         n       f    s               f
# 6554     p         f           s         e       f    y               f
# 6555     p         k           s         e       f    f               f
# 6556     p         f           y         e       f    s               f
# 6557     p         f           s         n       f    s               f
# 6559     p         x           s         n       f    y               f
# 6560     p         k           s         n       f    y               f
# 6561     p         f           s         n       f    f               f
# 6562     p         f           s         n       f    y               f
# 6563     p         x           s         n       f    y               f
# 6564     p         f           s         n       f    y               f
# 6565     p         f           y         e       f    f               f
# 6566     p         f           y         e       f    y               f
# 6567     p         f           s         n       f    f               f
# 6568     p         x           s         e       f    f               f
# 6569     p         x           s         n       f    s               f
# 6570     p         x           s         e       f    y               f
# 6571     p         x           s         e       f    s               f
# 6572     p         f           y         e       f    f               f
# 6573     p         x           s         e       f    y               f
# 6574     p         k           s         e       f    y               f
# 6575     p         x           y         e       f    f               f
# 6576     p         f           s         n       f    f               f
# 6577     p         f           s         n       f    y               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8071     e         k           s         n       f    n               a
# 8073     e         k           s         n       f    n               a
# 8074     e         b           f         g       f    n               f
# 8075     e         f           s         n       f    n               a
# 8076     e         b           s         n       f    n               a
# 8077     e         f           s         n       f    n               a
# 8078     e         b           f         g       f    n               f
# 8084     e         b           f         g       f    n               f
# 8085     e         k           f         w       f    n               f
# 8086     e         k           s         n       f    n               a
# 8088     e         k           s         n       f    n               a
# 8094     e         b           s         g       f    n               f
# 8096     e         k           f         w       f    n               f
# 8099     e         k           f         w       f    n               f
# 8100     e         f           s         n       f    n               a
# 8102     e         x           s         n       f    n               a
# 8103     e         k           s         n       f    n               a
# 8104     e         k           s         n       f    n               a
# 8105     e         k           s         n       f    n               a
# 8106     e         k           s         n       f    n               a
# 8107     e         x           s         n       f    n               a
# 8109     e         b           s         w       f    n               f
# 8110     e         x           s         n       f    n               a
# 8111     e         k           s         w       f    n               f
# 8112     e         k           s         n       f    n               a
# 8115     e         x           s         n       f    n               a
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 6547            c         n          b  ...                        s
# 6548            c         n          b  ...                        s
# 6549            c         n          b  ...                        s
# 6550            c         n          b  ...                        k
# 6551            c         n          b  ...                        s
# 6552            c         n          b  ...                        s
# 6553            c         n          b  ...                        k
# 6554            c         n          b  ...                        k
# 6555            c         n          b  ...                        k
# 6556            c         n          b  ...                        s
# 6557            c         n          b  ...                        k
# 6559            c         n          b  ...                        s
# 6560            c         n          b  ...                        s
# 6561            c         n          b  ...                        k
# 6562            c         n          b  ...                        s
# 6563            c         n          b  ...                        s
# 6564            c         n          b  ...                        k
# 6565            c         n          b  ...                        s
# 6566            c         n          b  ...                        k
# 6567            c         n          b  ...                        s
# 6568            c         n          b  ...                        k
# 6569            c         n          b  ...                        k
# 6570            c         n          b  ...                        s
# 6571            c         n          b  ...                        k
# 6572            c         n          b  ...                        s
# 6573            c         n          b  ...                        k
# 6574            c         n          b  ...                        s
# 6575            c         n          b  ...                        s
# 6576            c         n          b  ...                        s
# 6577            c         n          b  ...                        k
# ...           ...       ...        ...  ...                      ...
# 8071            c         b          n  ...                        s
# 8073            c         b          n  ...                        s
# 8074            w         b          w  ...                        k
# 8075            c         b          o  ...                        s
# 8076            c         b          o  ...                        s
# 8077            c         b          o  ...                        s
# 8078            w         b          g  ...                        s
# 8084            w         b          p  ...                        k
# 8085            w         b          g  ...                        k
# 8086            c         b          n  ...                        s
# 8088            c         b          n  ...                        s
# 8094            w         b          g  ...                        s
# 8096            w         b          w  ...                        s
# 8099            w         b          w  ...                        k
# 8100            c         b          o  ...                        s
# 8102            c         b          y  ...                        s
# 8103            c         b          y  ...                        s
# 8104            c         b          y  ...                        s
# 8105            c         b          y  ...                        s
# 8106            c         b          o  ...                        s
# 8107            c         b          y  ...                        s
# 8109            w         b          w  ...                        s
# 8110            c         b          o  ...                        s
# 8111            w         b          p  ...                        s
# 8112            c         b          o  ...                        s
# 8115            c         b          y  ...                        s
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 6547                      p                      w         p          w
# 6548                      w                      p         p          w
# 6549                      w                      p         p          w
# 6550                      p                      p         p          w
# 6551                      p                      w         p          w
# 6552                      w                      p         p          w
# 6553                      p                      p         p          w
# 6554                      w                      w         p          w
# 6555                      w                      p         p          w
# 6556                      w                      w         p          w
# 6557                      p                      w         p          w
# 6559                      p                      w         p          w
# 6560                      p                      w         p          w
# 6561                      w                      p         p          w
# 6562                      w                      w         p          w
# 6563                      w                      p         p          w
# 6564                      w                      w         p          w
# 6565                      p                      p         p          w
# 6566                      p                      p         p          w
# 6567                      p                      w         p          w
# 6568                      w                      p         p          w
# 6569                      w                      w         p          w
# 6570                      p                      p         p          w
# 6571                      p                      p         p          w
# 6572                      p                      w         p          w
# 6573                      p                      w         p          w
# 6574                      p                      w         p          w
# 6575                      w                      p         p          w
# 6576                      w                      p         p          w
# 6577                      p                      p         p          w
# ...                     ...                    ...       ...        ...
# 8071                      o                      o         p          o
# 8073                      o                      o         p          n
# 8074                      w                      w         p          w
# 8075                      o                      o         p          o
# 8076                      o                      o         p          n
# 8077                      o                      o         p          n
# 8078                      w                      w         p          w
# 8084                      w                      w         p          w
# 8085                      w                      w         p          w
# 8086                      o                      o         p          n
# 8088                      o                      o         p          o
# 8094                      w                      w         p          w
# 8096                      w                      w         p          w
# 8099                      w                      w         p          w
# 8100                      o                      o         p          n
# 8102                      o                      o         p          n
# 8103                      o                      o         p          n
# 8104                      o                      o         p          o
# 8105                      o                      o         p          n
# 8106                      o                      o         p          o
# 8107                      o                      o         p          o
# 8109                      w                      w         p          w
# 8110                      o                      o         p          o
# 8111                      w                      w         p          w
# 8112                      o                      o         p          n
# 8115                      o                      o         p          o
# 8119                      o                      o         p          o
# 8120                      o                      o         p          n
# 8121                      o                      o         p          o
# 8123                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 6547           o         e                 w          v       p
# 6548           o         e                 w          v       l
# 6549           o         e                 w          v       p
# 6550           o         e                 w          v       p
# 6551           o         e                 w          v       p
# 6552           o         e                 w          v       p
# 6553           o         e                 w          v       d
# 6554           o         e                 w          v       p
# 6555           o         e                 w          v       p
# 6556           o         e                 w          v       p
# 6557           o         e                 w          v       p
# 6559           o         e                 w          v       l
# 6560           o         e                 w          v       l
# 6561           o         e                 w          v       d
# 6562           o         e                 w          v       d
# 6563           o         e                 w          v       p
# 6564           o         e                 w          v       d
# 6565           o         e                 w          v       p
# 6566           o         e                 w          v       d
# 6567           o         e                 w          v       l
# 6568           o         e                 w          v       l
# 6569           o         e                 w          v       p
# 6570           o         e                 w          v       p
# 6571           o         e                 w          v       d
# 6572           o         e                 w          v       l
# 6573           o         e                 w          v       p
# 6574           o         e                 w          v       l
# 6575           o         e                 w          v       p
# 6576           o         e                 w          v       p
# 6577           o         e                 w          v       l
# ...          ...       ...               ...        ...     ...
# 8071           o         p                 y          v       l
# 8073           o         p                 y          v       l
# 8074           t         p                 w          n       g
# 8075           o         p                 o          c       l
# 8076           o         p                 y          c       l
# 8077           o         p                 o          v       l
# 8078           t         p                 w          s       g
# 8084           t         p                 w          s       g
# 8085           t         p                 w          s       g
# 8086           o         p                 o          v       l
# 8088           o         p                 n          v       l
# 8094           t         p                 w          n       g
# 8096           t         p                 w          n       g
# 8099           t         p                 w          s       g
# 8100           o         p                 b          v       l
# 8102           o         p                 n          c       l
# 8103           o         p                 o          c       l
# 8104           o         p                 n          v       l
# 8105           o         p                 y          v       l
# 8106           o         p                 n          v       l
# 8107           o         p                 n          c       l
# 8109           t         p                 w          n       g
# 8110           o         p                 n          v       l
# 8111           t         p                 w          n       g
# 8112           o         p                 b          v       l
# 8115           o         p                 o          v       l
# 8119           o         p                 b          c       l
# 8120           o         p                 b          v       l
# 8121           o         p                 b          c       l
# 8123           o         p                 o          c       l
#
# [2438 rows x 23 columns]

# %%
remaining_data = np.array(remaining_data)

# %%
remaining_data
# Out:
# array([['p', 'f', 'y', ..., 'w', 'v', 'p'],
#        ['p', 'f', 'y', ..., 'w', 'v', 'l'],
#        ['p', 'x', 'y', ..., 'w', 'v', 'p'],
#        ...,
#        ['e', 'x', 's', ..., 'b', 'v', 'l'],
#        ['e', 'f', 's', ..., 'b', 'c', 'l'],
#        ['e', 'x', 's', ..., 'o', 'c', 'l']], dtype=object)

# %%
random_indices = np.random.choice(np.arange(0,2438),size=(2438,))

# %%
remaining_data = remaining_data[random_indices]

# %%
remaining_data
# Out:
# array([['e', 'b', 's', ..., 'o', 'c', 'l'],
#        ['p', 'k', 's', ..., 'w', 'v', 'l'],
#        ['p', 'k', 's', ..., 'w', 'v', 'p'],
#        ...,
#        ['p', 'k', 'y', ..., 'w', 'v', 'd'],
#        ['p', 'f', 's', ..., 'w', 'v', 'd'],
#        ['p', 'x', 'y', ..., 'w', 'v', 'l']], dtype=object)

# %%
remaining_data = pd.DataFrame(data=remaining_data,columns=data.columns)

# %%
remaining_data
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        e         b           s         n       f    n               a
# 1        p         k           s         n       f    y               f
# 2        p         k           s         n       f    y               f
# 3        e         f           y         n       t    n               f
# 4        e         f           f         e       t    n               f
# 5        e         x           s         n       f    n               a
# 6        e         f           s         n       t    n               f
# 7        p         k           s         n       f    s               f
# 8        e         k           s         n       f    n               a
# 9        e         f           f         g       t    n               f
# 10       p         k           y         n       f    s               f
# 11       p         x           s         e       f    y               f
# 12       p         k           s         n       f    s               f
# 13       e         f           f         g       t    n               f
# 14       p         x           s         n       f    s               f
# 15       p         x           s         n       f    s               f
# 16       p         k           y         e       f    y               f
# 17       p         k           s         e       f    s               f
# 18       p         k           s         e       f    s               f
# 19       p         x           y         e       f    f               f
# 20       e         k           s         p       t    n               f
# 21       e         x           s         n       f    n               a
# 22       p         k           s         e       f    f               f
# 23       p         k           s         e       f    f               f
# 24       e         f           f         e       t    n               f
# 25       p         k           y         e       f    f               f
# 26       e         f           f         e       t    n               f
# 27       e         k           s         n       f    n               a
# 28       p         k           s         e       f    y               f
# 29       p         k           s         e       f    y               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 2408     e         b           f         g       f    n               f
# 2409     e         f           y         e       t    n               f
# 2410     p         k           y         n       f    f               f
# 2411     p         f           y         e       f    f               f
# 2412     e         f           y         e       t    n               f
# 2413     e         f           y         g       t    n               f
# 2414     e         f           y         p       t    n               f
# 2415     e         f           f         g       t    n               f
# 2416     e         x           s         n       f    n               a
# 2417     e         f           y         g       t    n               f
# 2418     p         x           y         c       f    m               a
# 2419     e         x           y         p       t    n               f
# 2420     e         f           y         e       t    n               f
# 2421     p         k           s         n       f    y               f
# 2422     e         x           y         b       t    n               f
# 2423     e         f           s         n       f    n               a
# 2424     p         k           y         e       f    y               f
# 2425     e         f           f         e       t    n               f
# 2426     p         f           s         e       f    f               f
# 2427     e         f           f         e       t    n               f
# 2428     e         x           f         w       f    n               f
# 2429     e         b           f         w       f    n               f
# 2430     p         k           s         e       f    s               f
# 2431     e         x           f         g       f    n               f
# 2432     e         f           s         p       t    n               f
# 2433     p         k           y         e       f    f               f
# 2434     e         x           s         w       f    n               f
# 2435     p         k           y         n       f    s               f
# 2436     p         f           s         n       f    s               f
# 2437     p         x           y         e       f    s               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0               c         b          n  ...                        s
# 1               c         n          b  ...                        s
# 2               c         n          b  ...                        s
# 3               c         b          u  ...                        s
# 4               c         b          u  ...                        s
# 5               c         b          y  ...                        s
# 6               c         b          w  ...                        s
# 7               c         n          b  ...                        s
# 8               c         b          y  ...                        s
# 9               c         b          u  ...                        s
# 10              c         n          b  ...                        s
# 11              c         n          b  ...                        k
# 12              c         n          b  ...                        s
# 13              c         b          u  ...                        s
# 14              c         n          b  ...                        s
# 15              c         n          b  ...                        s
# 16              c         n          b  ...                        k
# 17              c         n          b  ...                        s
# 18              c         n          b  ...                        s
# 19              c         n          b  ...                        k
# 20              c         b          w  ...                        s
# 21              c         b          n  ...                        s
# 22              c         n          b  ...                        k
# 23              c         n          b  ...                        s
# 24              c         b          n  ...                        s
# 25              c         n          b  ...                        s
# 26              c         b          p  ...                        s
# 27              c         b          y  ...                        s
# 28              c         n          b  ...                        s
# 29              c         n          b  ...                        s
# ...           ...       ...        ...  ...                      ...
# 2408            w         b          g  ...                        k
# 2409            c         b          p  ...                        s
# 2410            c         n          b  ...                        k
# 2411            c         n          b  ...                        s
# 2412            c         b          u  ...                        s
# 2413            c         b          p  ...                        s
# 2414            c         b          w  ...                        s
# 2415            c         b          u  ...                        s
# 2416            c         b          o  ...                        s
# 2417            c         b          n  ...                        s
# 2418            c         b          w  ...                        y
# 2419            c         b          e  ...                        s
# 2420            c         b          w  ...                        s
# 2421            c         n          b  ...                        s
# 2422            c         b          e  ...                        s
# 2423            c         b          o  ...                        s
# 2424            c         n          b  ...                        k
# 2425            c         b          w  ...                        s
# 2426            c         n          b  ...                        k
# 2427            c         b          w  ...                        s
# 2428            w         b          g  ...                        k
# 2429            w         b          g  ...                        s
# 2430            c         n          b  ...                        s
# 2431            w         b          p  ...                        s
# 2432            c         b          w  ...                        s
# 2433            c         n          b  ...                        k
# 2434            w         b          p  ...                        k
# 2435            c         n          b  ...                        s
# 2436            c         n          b  ...                        k
# 2437            c         n          b  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         o                      o         p          n
# 1                         p                      p         p          w
# 2                         p                      p         p          w
# 3                         p                      g         p          w
# 4                         g                      g         p          w
# 5                         o                      o         p          n
# 6                         w                      w         p          w
# 7                         p                      p         p          w
# 8                         o                      o         p          o
# 9                         w                      g         p          w
# 10                        p                      p         p          w
# 11                        w                      p         p          w
# 12                        p                      p         p          w
# 13                        w                      g         p          w
# 14                        w                      p         p          w
# 15                        p                      p         p          w
# 16                        w                      w         p          w
# 17                        w                      w         p          w
# 18                        w                      p         p          w
# 19                        w                      p         p          w
# 20                        w                      w         p          w
# 21                        o                      o         p          o
# 22                        w                      p         p          w
# 23                        w                      w         p          w
# 24                        w                      p         p          w
# 25                        p                      w         p          w
# 26                        w                      w         p          w
# 27                        o                      o         p          n
# 28                        p                      p         p          w
# 29                        p                      p         p          w
# ...                     ...                    ...       ...        ...
# 2408                      w                      w         p          w
# 2409                      p                      w         p          w
# 2410                      p                      p         p          w
# 2411                      p                      w         p          w
# 2412                      w                      g         p          w
# 2413                      g                      p         p          w
# 2414                      e                      w         p          w
# 2415                      w                      p         p          w
# 2416                      o                      o         p          n
# 2417                      w                      w         p          w
# 2418                      c                      c         p          w
# 2419                      e                      e         p          w
# 2420                      p                      w         p          w
# 2421                      p                      w         p          w
# 2422                      w                      e         p          w
# 2423                      o                      o         p          n
# 2424                      p                      p         p          w
# 2425                      p                      w         p          w
# 2426                      p                      w         p          w
# 2427                      g                      g         p          w
# 2428                      w                      w         p          w
# 2429                      w                      w         p          w
# 2430                      p                      w         p          w
# 2431                      w                      w         p          w
# 2432                      e                      e         p          w
# 2433                      p                      p         p          w
# 2434                      w                      w         p          w
# 2435                      w                      p         p          w
# 2436                      w                      p         p          w
# 2437                      w                      w         p          w
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 o          c       l
# 1              o         e                 w          v       l
# 2              o         e                 w          v       p
# 3              o         p                 k          y       d
# 4              o         p                 k          y       d
# 5              o         p                 n          c       l
# 6              t         p                 w          y       p
# 7              o         e                 w          v       l
# 8              o         p                 o          c       l
# 9              o         p                 k          v       d
# 10             o         e                 w          v       p
# 11             o         e                 w          v       l
# 12             o         e                 w          v       d
# 13             o         p                 n          v       d
# 14             o         e                 w          v       d
# 15             o         e                 w          v       d
# 16             o         e                 w          v       p
# 17             o         e                 w          v       l
# 18             o         e                 w          v       p
# 19             o         e                 w          v       p
# 20             t         e                 w          c       w
# 21             o         p                 b          c       l
# 22             o         e                 w          v       l
# 23             o         e                 w          v       l
# 24             o         p                 n          v       d
# 25             o         e                 w          v       p
# 26             o         p                 k          v       d
# 27             o         p                 y          v       l
# 28             o         e                 w          v       l
# 29             o         e                 w          v       l
# ...          ...       ...               ...        ...     ...
# 2408           t         p                 w          n       g
# 2409           o         p                 n          y       d
# 2410           o         e                 w          v       p
# 2411           o         e                 w          v       l
# 2412           o         p                 n          y       d
# 2413           o         p                 n          y       d
# 2414           t         e                 w          c       w
# 2415           o         p                 k          v       d
# 2416           o         p                 n          v       l
# 2417           o         p                 k          y       d
# 2418           n         n                 w          c       d
# 2419           t         e                 w          c       w
# 2420           o         p                 k          y       d
# 2421           o         e                 w          v       p
# 2422           t         e                 w          c       w
# 2423           o         p                 n          v       l
# 2424           o         e                 w          v       l
# 2425           o         p                 n          y       d
# 2426           o         e                 w          v       l
# 2427           o         p                 k          v       d
# 2428           t         p                 w          n       g
# 2429           t         p                 w          n       g
# 2430           o         e                 w          v       l
# 2431           t         p                 w          n       g
# 2432           t         e                 w          c       w
# 2433           o         e                 w          v       l
# 2434           t         p                 w          n       g
# 2435           o         e                 w          v       d
# 2436           o         e                 w          v       d
# 2437           o         e                 w          v       l
#
# [2438 rows x 23 columns]

# %%
cv_data = remaining_data.iloc[0:cv_data_len]

testing_data = remaining_data.iloc[cv_data_len:]

# %%
cv_data.shape
# Out:
# (1624, 23)

# %%
testing_data.shape
# Out:
# (814, 23)

# %%
cv_data
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        e         b           s         n       f    n               a
# 1        p         k           s         n       f    y               f
# 2        p         k           s         n       f    y               f
# 3        e         f           y         n       t    n               f
# 4        e         f           f         e       t    n               f
# 5        e         x           s         n       f    n               a
# 6        e         f           s         n       t    n               f
# 7        p         k           s         n       f    s               f
# 8        e         k           s         n       f    n               a
# 9        e         f           f         g       t    n               f
# 10       p         k           y         n       f    s               f
# 11       p         x           s         e       f    y               f
# 12       p         k           s         n       f    s               f
# 13       e         f           f         g       t    n               f
# 14       p         x           s         n       f    s               f
# 15       p         x           s         n       f    s               f
# 16       p         k           y         e       f    y               f
# 17       p         k           s         e       f    s               f
# 18       p         k           s         e       f    s               f
# 19       p         x           y         e       f    f               f
# 20       e         k           s         p       t    n               f
# 21       e         x           s         n       f    n               a
# 22       p         k           s         e       f    f               f
# 23       p         k           s         e       f    f               f
# 24       e         f           f         e       t    n               f
# 25       p         k           y         e       f    f               f
# 26       e         f           f         e       t    n               f
# 27       e         k           s         n       f    n               a
# 28       p         k           s         e       f    y               f
# 29       p         k           s         e       f    y               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 1594     p         k           s         e       f    f               f
# 1595     p         k           s         n       f    y               f
# 1596     p         k           y         n       f    y               f
# 1597     p         x           y         e       f    f               f
# 1598     p         f           y         n       f    m               f
# 1599     e         k           f         w       f    n               f
# 1600     p         k           s         e       f    s               f
# 1601     p         x           s         n       f    s               f
# 1602     e         x           y         e       t    n               f
# 1603     p         x           s         n       f    y               f
# 1604     p         f           y         n       f    y               f
# 1605     p         k           y         e       f    y               f
# 1606     e         f           y         n       t    n               f
# 1607     e         x           s         w       f    n               f
# 1608     p         k           y         e       f    y               f
# 1609     e         f           y         n       t    n               f
# 1610     e         k           s         b       t    n               f
# 1611     p         k           y         e       f    f               f
# 1612     e         b           s         n       f    n               a
# 1613     e         f           y         n       t    n               f
# 1614     p         f           y         e       f    f               f
# 1615     e         f           y         n       t    n               f
# 1616     p         x           y         e       f    f               f
# 1617     e         f           y         n       t    n               f
# 1618     e         k           s         w       f    n               f
# 1619     e         f           s         e       t    n               f
# 1620     e         f           y         n       t    n               f
# 1621     p         k           y         n       f    f               f
# 1622     p         x           s         e       f    y               f
# 1623     p         k           s         n       f    y               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0               c         b          n  ...                        s
# 1               c         n          b  ...                        s
# 2               c         n          b  ...                        s
# 3               c         b          u  ...                        s
# 4               c         b          u  ...                        s
# 5               c         b          y  ...                        s
# 6               c         b          w  ...                        s
# 7               c         n          b  ...                        s
# 8               c         b          y  ...                        s
# 9               c         b          u  ...                        s
# 10              c         n          b  ...                        s
# 11              c         n          b  ...                        k
# 12              c         n          b  ...                        s
# 13              c         b          u  ...                        s
# 14              c         n          b  ...                        s
# 15              c         n          b  ...                        s
# 16              c         n          b  ...                        k
# 17              c         n          b  ...                        s
# 18              c         n          b  ...                        s
# 19              c         n          b  ...                        k
# 20              c         b          w  ...                        s
# 21              c         b          n  ...                        s
# 22              c         n          b  ...                        k
# 23              c         n          b  ...                        s
# 24              c         b          n  ...                        s
# 25              c         n          b  ...                        s
# 26              c         b          p  ...                        s
# 27              c         b          y  ...                        s
# 28              c         n          b  ...                        s
# 29              c         n          b  ...                        s
# ...           ...       ...        ...  ...                      ...
# 1594            c         n          b  ...                        s
# 1595            c         n          b  ...                        k
# 1596            c         n          b  ...                        k
# 1597            c         n          b  ...                        s
# 1598            c         b          y  ...                        y
# 1599            w         b          w  ...                        k
# 1600            c         n          b  ...                        k
# 1601            c         n          b  ...                        s
# 1602            c         b          w  ...                        s
# 1603            c         n          b  ...                        s
# 1604            c         n          b  ...                        k
# 1605            c         n          b  ...                        s
# 1606            c         b          u  ...                        s
# 1607            w         b          g  ...                        k
# 1608            c         n          b  ...                        k
# 1609            c         b          n  ...                        s
# 1610            c         b          e  ...                        s
# 1611            c         n          b  ...                        s
# 1612            c         b          n  ...                        s
# 1613            c         b          p  ...                        s
# 1614            c         n          b  ...                        s
# 1615            c         b          u  ...                        s
# 1616            c         n          b  ...                        s
# 1617            c         b          u  ...                        s
# 1618            w         b          p  ...                        s
# 1619            c         b          w  ...                        s
# 1620            c         b          e  ...                        s
# 1621            c         n          b  ...                        k
# 1622            c         n          b  ...                        k
# 1623            c         n          b  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         o                      o         p          n
# 1                         p                      p         p          w
# 2                         p                      p         p          w
# 3                         p                      g         p          w
# 4                         g                      g         p          w
# 5                         o                      o         p          n
# 6                         w                      w         p          w
# 7                         p                      p         p          w
# 8                         o                      o         p          o
# 9                         w                      g         p          w
# 10                        p                      p         p          w
# 11                        w                      p         p          w
# 12                        p                      p         p          w
# 13                        w                      g         p          w
# 14                        w                      p         p          w
# 15                        p                      p         p          w
# 16                        w                      w         p          w
# 17                        w                      w         p          w
# 18                        w                      p         p          w
# 19                        w                      p         p          w
# 20                        w                      w         p          w
# 21                        o                      o         p          o
# 22                        w                      p         p          w
# 23                        w                      w         p          w
# 24                        w                      p         p          w
# 25                        p                      w         p          w
# 26                        w                      w         p          w
# 27                        o                      o         p          n
# 28                        p                      p         p          w
# 29                        p                      p         p          w
# ...                     ...                    ...       ...        ...
# 1594                      p                      w         p          w
# 1595                      w                      w         p          w
# 1596                      p                      w         p          w
# 1597                      p                      p         p          w
# 1598                      c                      c         p          w
# 1599                      w                      w         p          w
# 1600                      w                      w         p          w
# 1601                      w                      p         p          w
# 1602                      w                      w         p          w
# 1603                      w                      w         p          w
# 1604                      p                      p         p          w
# 1605                      p                      w         p          w
# 1606                      g                      p         p          w
# 1607                      w                      w         p          w
# 1608                      p                      w         p          w
# 1609                      p                      p         p          w
# 1610                      w                      e         p          w
# 1611                      p                      p         p          w
# 1612                      o                      o         p          o
# 1613                      g                      g         p          w
# 1614                      w                      p         p          w
# 1615                      g                      w         p          w
# 1616                      p                      w         p          w
# 1617                      g                      g         p          w
# 1618                      w                      w         p          w
# 1619                      w                      e         p          w
# 1620                      e                      w         p          w
# 1621                      w                      w         p          w
# 1622                      p                      p         p          w
# 1623                      p                      p         p          w
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 o          c       l
# 1              o         e                 w          v       l
# 2              o         e                 w          v       p
# 3              o         p                 k          y       d
# 4              o         p                 k          y       d
# 5              o         p                 n          c       l
# 6              t         p                 w          y       p
# 7              o         e                 w          v       l
# 8              o         p                 o          c       l
# 9              o         p                 k          v       d
# 10             o         e                 w          v       p
# 11             o         e                 w          v       l
# 12             o         e                 w          v       d
# 13             o         p                 n          v       d
# 14             o         e                 w          v       d
# 15             o         e                 w          v       d
# 16             o         e                 w          v       p
# 17             o         e                 w          v       l
# 18             o         e                 w          v       p
# 19             o         e                 w          v       p
# 20             t         e                 w          c       w
# 21             o         p                 b          c       l
# 22             o         e                 w          v       l
# 23             o         e                 w          v       l
# 24             o         p                 n          v       d
# 25             o         e                 w          v       p
# 26             o         p                 k          v       d
# 27             o         p                 y          v       l
# 28             o         e                 w          v       l
# 29             o         e                 w          v       l
# ...          ...       ...               ...        ...     ...
# 1594           o         e                 w          v       d
# 1595           o         e                 w          v       d
# 1596           o         e                 w          v       d
# 1597           o         e                 w          v       l
# 1598           n         n                 w          c       d
# 1599           t         p                 w          n       g
# 1600           o         e                 w          v       l
# 1601           o         e                 w          v       l
# 1602           t         e                 w          c       w
# 1603           o         e                 w          v       d
# 1604           o         e                 w          v       p
# 1605           o         e                 w          v       p
# 1606           o         p                 k          y       d
# 1607           t         p                 w          s       g
# 1608           o         e                 w          v       l
# 1609           o         p                 k          y       d
# 1610           t         e                 w          c       w
# 1611           o         e                 w          v       l
# 1612           o         p                 y          c       l
# 1613           o         p                 n          y       d
# 1614           o         e                 w          v       d
# 1615           o         p                 k          y       d
# 1616           o         e                 w          v       p
# 1617           o         p                 k          y       d
# 1618           t         p                 w          s       g
# 1619           t         e                 w          c       w
# 1620           t         e                 w          c       w
# 1621           o         e                 w          v       d
# 1622           o         e                 w          v       l
# 1623           o         e                 w          v       d
#
# [1624 rows x 23 columns]

# %%
testing_data
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 1624     p         k           y         n       f    y               f
# 1625     e         k           f         w       f    n               f
# 1626     e         f           y         n       t    n               f
# 1627     p         f           y         e       f    y               f
# 1628     p         k           y         e       f    s               f
# 1629     e         x           y         n       t    n               f
# 1630     e         x           y         w       f    n               f
# 1631     e         b           f         g       f    n               f
# 1632     p         f           s         e       f    f               f
# 1633     p         x           y         e       f    s               f
# 1634     p         f           s         n       f    y               f
# 1635     p         k           y         n       f    f               f
# 1636     p         x           s         n       f    s               f
# 1637     p         f           s         n       f    y               f
# 1638     p         k           y         n       f    f               f
# 1639     e         x           s         n       f    n               a
# 1640     p         k           y         e       f    f               f
# 1641     e         f           y         e       t    n               f
# 1642     e         f           y         e       t    n               f
# 1643     e         f           y         e       t    n               f
# 1644     e         f           s         n       f    n               a
# 1645     p         f           y         n       f    f               f
# 1646     e         f           f         g       t    n               f
# 1647     e         x           s         n       f    n               a
# 1648     p         k           s         n       f    s               f
# 1649     e         x           s         g       f    n               f
# 1650     e         f           s         n       f    n               a
# 1651     p         k           s         n       f    f               f
# 1652     p         k           y         n       f    y               f
# 1653     e         k           f         c       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 2408     e         b           f         g       f    n               f
# 2409     e         f           y         e       t    n               f
# 2410     p         k           y         n       f    f               f
# 2411     p         f           y         e       f    f               f
# 2412     e         f           y         e       t    n               f
# 2413     e         f           y         g       t    n               f
# 2414     e         f           y         p       t    n               f
# 2415     e         f           f         g       t    n               f
# 2416     e         x           s         n       f    n               a
# 2417     e         f           y         g       t    n               f
# 2418     p         x           y         c       f    m               a
# 2419     e         x           y         p       t    n               f
# 2420     e         f           y         e       t    n               f
# 2421     p         k           s         n       f    y               f
# 2422     e         x           y         b       t    n               f
# 2423     e         f           s         n       f    n               a
# 2424     p         k           y         e       f    y               f
# 2425     e         f           f         e       t    n               f
# 2426     p         f           s         e       f    f               f
# 2427     e         f           f         e       t    n               f
# 2428     e         x           f         w       f    n               f
# 2429     e         b           f         w       f    n               f
# 2430     p         k           s         e       f    s               f
# 2431     e         x           f         g       f    n               f
# 2432     e         f           s         p       t    n               f
# 2433     p         k           y         e       f    f               f
# 2434     e         x           s         w       f    n               f
# 2435     p         k           y         n       f    s               f
# 2436     p         f           s         n       f    s               f
# 2437     p         x           y         e       f    s               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 1624            c         n          b  ...                        k
# 1625            w         b          w  ...                        k
# 1626            c         b          n  ...                        s
# 1627            c         n          b  ...                        k
# 1628            c         n          b  ...                        k
# 1629            c         b          e  ...                        s
# 1630            c         n          h  ...                        f
# 1631            w         b          p  ...                        k
# 1632            c         n          b  ...                        s
# 1633            c         n          b  ...                        s
# 1634            c         n          b  ...                        s
# 1635            c         n          b  ...                        s
# 1636            c         n          b  ...                        s
# 1637            c         n          b  ...                        s
# 1638            c         n          b  ...                        s
# 1639            c         b          o  ...                        s
# 1640            c         n          b  ...                        s
# 1641            c         b          w  ...                        s
# 1642            c         b          n  ...                        s
# 1643            c         b          u  ...                        s
# 1644            c         b          y  ...                        s
# 1645            c         n          b  ...                        k
# 1646            c         b          u  ...                        s
# 1647            c         b          y  ...                        s
# 1648            c         n          b  ...                        s
# 1649            w         b          w  ...                        k
# 1650            c         b          o  ...                        s
# 1651            c         n          b  ...                        k
# 1652            c         n          b  ...                        s
# 1653            w         n          w  ...                        s
# ...           ...       ...        ...  ...                      ...
# 2408            w         b          g  ...                        k
# 2409            c         b          p  ...                        s
# 2410            c         n          b  ...                        k
# 2411            c         n          b  ...                        s
# 2412            c         b          u  ...                        s
# 2413            c         b          p  ...                        s
# 2414            c         b          w  ...                        s
# 2415            c         b          u  ...                        s
# 2416            c         b          o  ...                        s
# 2417            c         b          n  ...                        s
# 2418            c         b          w  ...                        y
# 2419            c         b          e  ...                        s
# 2420            c         b          w  ...                        s
# 2421            c         n          b  ...                        s
# 2422            c         b          e  ...                        s
# 2423            c         b          o  ...                        s
# 2424            c         n          b  ...                        k
# 2425            c         b          w  ...                        s
# 2426            c         n          b  ...                        k
# 2427            c         b          w  ...                        s
# 2428            w         b          g  ...                        k
# 2429            w         b          g  ...                        s
# 2430            c         n          b  ...                        s
# 2431            w         b          p  ...                        s
# 2432            c         b          w  ...                        s
# 2433            c         n          b  ...                        k
# 2434            w         b          p  ...                        k
# 2435            c         n          b  ...                        s
# 2436            c         n          b  ...                        k
# 2437            c         n          b  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 1624                      w                      w         p          w
# 1625                      w                      w         p          w
# 1626                      g                      w         p          w
# 1627                      p                      w         p          w
# 1628                      w                      p         p          w
# 1629                      e                      w         p          w
# 1630                      w                      w         p          w
# 1631                      w                      w         p          w
# 1632                      p                      p         p          w
# 1633                      w                      w         p          w
# 1634                      w                      w         p          w
# 1635                      w                      p         p          w
# 1636                      p                      w         p          w
# 1637                      p                      p         p          w
# 1638                      p                      w         p          w
# 1639                      o                      o         p          n
# 1640                      p                      p         p          w
# 1641                      g                      p         p          w
# 1642                      p                      w         p          w
# 1643                      p                      w         p          w
# 1644                      o                      o         p          n
# 1645                      p                      w         p          w
# 1646                      p                      g         p          w
# 1647                      o                      o         p          n
# 1648                      w                      p         p          w
# 1649                      w                      w         p          w
# 1650                      o                      o         p          n
# 1651                      p                      p         p          w
# 1652                      w                      w         p          w
# 1653                      w                      n         p          w
# ...                     ...                    ...       ...        ...
# 2408                      w                      w         p          w
# 2409                      p                      w         p          w
# 2410                      p                      p         p          w
# 2411                      p                      w         p          w
# 2412                      w                      g         p          w
# 2413                      g                      p         p          w
# 2414                      e                      w         p          w
# 2415                      w                      p         p          w
# 2416                      o                      o         p          n
# 2417                      w                      w         p          w
# 2418                      c                      c         p          w
# 2419                      e                      e         p          w
# 2420                      p                      w         p          w
# 2421                      p                      w         p          w
# 2422                      w                      e         p          w
# 2423                      o                      o         p          n
# 2424                      p                      p         p          w
# 2425                      p                      w         p          w
# 2426                      p                      w         p          w
# 2427                      g                      g         p          w
# 2428                      w                      w         p          w
# 2429                      w                      w         p          w
# 2430                      p                      w         p          w
# 2431                      w                      w         p          w
# 2432                      e                      e         p          w
# 2433                      p                      p         p          w
# 2434                      w                      w         p          w
# 2435                      w                      p         p          w
# 2436                      w                      p         p          w
# 2437                      w                      w         p          w
#
#      ring-number ring-type spore-print-color population habitat
# 1624           o         e                 w          v       l
# 1625           t         p                 w          s       g
# 1626           o         p                 n          v       d
# 1627           o         e                 w          v       p
# 1628           o         e                 w          v       l
# 1629           t         e                 w          c       w
# 1630           o         f                 h          y       d
# 1631           t         p                 w          s       g
# 1632           o         e                 w          v       d
# 1633           o         e                 w          v       p
# 1634           o         e                 w          v       d
# 1635           o         e                 w          v       l
# 1636           o         e                 w          v       l
# 1637           o         e                 w          v       d
# 1638           o         e                 w          v       p
# 1639           o         p                 n          v       l
# 1640           o         e                 w          v       d
# 1641           o         p                 k          y       d
# 1642           o         p                 k          y       d
# 1643           o         p                 n          v       d
# 1644           o         p                 n          c       l
# 1645           o         e                 w          v       p
# 1646           o         p                 k          v       d
# 1647           o         p                 b          c       l
# 1648           o         e                 w          v       l
# 1649           t         p                 w          s       g
# 1650           o         p                 b          c       l
# 1651           o         e                 w          v       d
# 1652           o         e                 w          v       p
# 1653           o         e                 w          v       l
# ...          ...       ...               ...        ...     ...
# 2408           t         p                 w          n       g
# 2409           o         p                 n          y       d
# 2410           o         e                 w          v       p
# 2411           o         e                 w          v       l
# 2412           o         p                 n          y       d
# 2413           o         p                 n          y       d
# 2414           t         e                 w          c       w
# 2415           o         p                 k          v       d
# 2416           o         p                 n          v       l
# 2417           o         p                 k          y       d
# 2418           n         n                 w          c       d
# 2419           t         e                 w          c       w
# 2420           o         p                 k          y       d
# 2421           o         e                 w          v       p
# 2422           t         e                 w          c       w
# 2423           o         p                 n          v       l
# 2424           o         e                 w          v       l
# 2425           o         p                 n          y       d
# 2426           o         e                 w          v       l
# 2427           o         p                 k          v       d
# 2428           t         p                 w          n       g
# 2429           t         p                 w          n       g
# 2430           o         e                 w          v       l
# 2431           t         p                 w          n       g
# 2432           t         e                 w          c       w
# 2433           o         e                 w          v       l
# 2434           t         p                 w          n       g
# 2435           o         e                 w          v       d
# 2436           o         e                 w          v       d
# 2437           o         e                 w          v       l
#
# [814 rows x 23 columns]

# %%
def lidstone_smoothing(column_name,category,alpha):
    
    D = dict()
    
    train_unique_feature_values = training_data[training_data['class'] == category][column_name].unique()
    
    data_unique_feature_values = data[column_name].unique()
    
    for feature_value in data_unique_feature_values:
        
        if feature_value not in train_unique_feature_values:
            
            D[feature_value] = alpha/(training_data[training_data['class'] == category].shape[0] + (data_unique_feature_values.shape[0]*alpha))
            
        else:
            
            D[feature_value] = np.count_nonzero(training_data[training_data['class'] == category][column_name] == feature_value)/training_data[training_data['class'] == category].shape[0]
            
    return D

# %%
D_of_D = {'p':{},'e':{}}

for category in ['p','e']:
    
    for column_name in data.columns[1:]:
        
        D_of_D[category][column_name] = lidstone_smoothing(column_name,category,0.75)

# %%
D_of_D
# Out:
# {'p': {'cap-shape': {'x': 0.5255012310939149,
#    'b': 0.01618009145269082,
#    's': 0.0002633889376646181,
#    'f': 0.4400281392894829,
#    'k': 0.017587055926837847,
#    'c': 0.0007034822370735139},
#   'cap-surface': {'s': 0.29229686950404504,
#    'y': 0.43897291593387266,
#    'f': 0.2673232500879353,
#    'g': 0.0014069644741470278},
#   'cap-color': {'n': 0.1829053816391136,
#    'y': 0.23355610270840663,
#    'w': 0.11255715793176223,
#    'g': 0.2842068237776996,
#    'e': 0.1136123812873725,
#    'p': 0.03095321843123461,
#    'b': 0.042208934224410834,
#    'u': 0.00026311173478337136,
#    'c': 0.00026311173478337136,
#    'r': 0.00026311173478337136},
#   'bruises': {'t': 0.21948645796693633, 'f': 0.7805135420330637},
#   'odor': {'p': 0.09004572634540978,
#    'a': 0.0002631809807877884,
#    'l': 0.0002631809807877884,
#    'n': 0.03939500527611678,
#    'f': 0.6408723179739712,
#    'c': 0.06753429475905734,
#    'y': 0.08476960956735842,
#    's': 0.07703130495954977,
#    'm': 0.00035174111853675694},
#   'gill-attachment': {'f': 1.0, 'a': 0.00026366672525927225},
#   'gill-spacing': {'c': 0.9634189236721773, 'w': 0.036581076327822724},
#   'gill-size': {'n': 0.41716496658459373, 'b': 0.5828350334154062},
#   'gill-color': {'k': 0.022511431586352444,
#    'n': 0.03939500527611678,
#    'g': 0.1772775237425255,
#    'p': 0.22511431586352446,
#    'w': 0.07914175167077031,
#    'h': 0.18571931058740768,
#    'u': 0.016883573689764335,
#    'e': 0.0002629733520336606,
#    'b': 0.24551530073865635,
#    'r': 0.008441786844882167,
#    'y': 0.0002629733520336606,
#    'o': 0.0002629733520336606},
#   'stalk-shape': {'e': 0.6531832571227576, 't': 0.34681674287724235},
#   'stalk-root': {'e': 0.09004572634540978,
#    'c': 0.00035174111853675694,
#    'b': 0.6528315160042208,
#    'r': 0.00026345832967418985,
#    '?': 0.2567710165318326},
#   'stalk-surface-above-ring': {'s': 0.3563137530777348,
#    'f': 0.050650721069293,
#    'k': 0.5930355258529723,
#    'y': 0.00026352775825720307},
#   'stalk-surface-below-ring': {'s': 0.3566654941962715,
#    'f': 0.050650721069293,
#    'y': 0.01160745691171298,
#    'k': 0.5810763278227224},
#   'stalk-color-above-ring': {'w': 0.42033063665142456,
#    'g': 0.0002631809807877884,
#    'p': 0.2754132958142807,
#    'n': 0.151952163207879,
#    'b': 0.151952163207879,
#    'e': 0.0002631809807877884,
#    'o': 0.0002631809807877884,
#    'c': 0.00035174111853675694,
#    'y': 0.0002631809807877884},
#   'stalk-color-below-ring': {'w': 0.4045022863172705,
#    'p': 0.27998593035525854,
#    'g': 0.0002631809807877884,
#    'b': 0.151952163207879,
#    'n': 0.15758002110446712,
#    'e': 0.0002631809807877884,
#    'y': 0.005627857896588111,
#    'o': 0.0002631809807877884,
#    'c': 0.00035174111853675694},
#   'veil-type': {'p': 1.0},
#   'veil-color': {'w': 1.0,
#    'n': 0.00026352775825720307,
#    'o': 0.00026352775825720307,
#    'y': 0.00026352775825720307},
#   'ring-number': {'o': 0.9743228983468167,
#    't': 0.0253253605346465,
#    'n': 0.00035174111853675694},
#   'ring-type': {'p': 0.28702075272599364,
#    'e': 0.2567710165318326,
#    'l': 0.455856489623637,
#    'f': 0.00026345832967418985,
#    'n': 0.00035174111853675694},
#   'spore-print-color': {'k': 0.07879001055223356,
#    'n': 0.07879001055223356,
#    'u': 0.0002631809807877884,
#    'h': 0.5571579317622231,
#    'w': 0.25993668659866337,
#    'r': 0.0253253605346465,
#    'o': 0.0002631809807877884,
#    'y': 0.0002631809807877884,
#    'b': 0.0002631809807877884},
#   'population': {'s': 0.12944073162152656,
#    'n': 0.0002633889376646181,
#    'a': 0.0002633889376646181,
#    'v': 0.6394653534998241,
#    'y': 0.2279282448118185,
#    'c': 0.0031656700668308124},
#   'habitat': {'u': 0.09567358424199789,
#    'g': 0.2602884277172001,
#    'm': 0.01266268026732325,
#    'd': 0.31023566654941964,
#    'p': 0.23179739711572284,
#    'w': 0.00026331958219959624,
#    'l': 0.08934224410833626}},
#  'e': {'cap-shape': {'x': 0.5666549419627155,
#    'b': 0.09004572634540978,
#    's': 0.011255715793176222,
#    'f': 0.3320436158986986,
#    'k': 0.0002633889376646181,
#    'c': 0.0002633889376646181},
#   'cap-surface': {'s': 0.24199788955328877,
#    'y': 0.34048540274358075,
#    'f': 0.4175167077031305,
#    'g': 0.00026352775825720307},
#   'cap-color': {'n': 0.29792472740063314,
#    'y': 0.14069644741470277,
#    'w': 0.1969750263805839,
#    'g': 0.24059092507914176,
#    'e': 0.12381287372493845,
#    'p': 0.00026311173478337136,
#    'b': 0.00026311173478337136,
#    'u': 0.00026311173478337136,
#    'c': 0.00026311173478337136,
#    'r': 0.00026311173478337136},
#   'bruises': {'t': 0.696095673584242, 'f': 0.303904326415758},
#   'odor': {'p': 0.0002631809807877884,
#    'a': 0.14069644741470277,
#    'l': 0.14069644741470277,
#    'n': 0.7186071051705945,
#    'f': 0.0002631809807877884,
#    'c': 0.0002631809807877884,
#    'y': 0.0002631809807877884,
#    's': 0.0002631809807877884,
#    'm': 0.0002631809807877884},
#   'gill-attachment': {'f': 1.0, 'a': 0.00026366672525927225},
#   'gill-spacing': {'c': 0.696095673584242, 'w': 0.303904326415758},
#   'gill-size': {'n': 0.06753429475905734, 'b': 0.9324657052409426},
#   'gill-color': {'k': 0.12099894477664438,
#    'n': 0.2588814632430531,
#    'g': 0.05346465001758706,
#    'p': 0.22018994020400984,
#    'w': 0.17938797045374605,
#    'h': 0.06753429475905734,
#    'u': 0.09954273654590222,
#    'e': 0.0002629733520336606,
#    'b': 0.0002629733520336606,
#    'r': 0.0002629733520336606,
#    'y': 0.0002629733520336606,
#    'o': 0.0002629733520336606},
#   'stalk-shape': {'e': 0.28139289482940555, 't': 0.7186071051705945},
#   'stalk-root': {'e': 0.303904326415758,
#    'c': 0.18009145269081955,
#    'b': 0.4484699261343651,
#    'r': 0.06753429475905734,
#    '?': 0.00026345832967418985},
#   'stalk-surface-above-ring': {'s': 0.8649314104818854,
#    'f': 0.13506858951811468,
#    'k': 0.00026352775825720307,
#    'y': 0.00026352775825720307},
#   'stalk-surface-below-ring': {'s': 0.797397115722828,
#    'f': 0.13506858951811468,
#    'y': 0.06753429475905734,
#    'k': 0.00026352775825720307},
#   'stalk-color-above-ring': {'w': 0.7228279985930355,
#    'g': 0.13893774182201898,
#    'p': 0.13823425958494548,
#    'n': 0.0002631809807877884,
#    'b': 0.0002631809807877884,
#    'e': 0.0002631809807877884,
#    'o': 0.0002631809807877884,
#    'c': 0.0002631809807877884,
#    'y': 0.0002631809807877884},
#   'stalk-color-below-ring': {'w': 0.7210692930003517,
#    'p': 0.13999296517762927,
#    'g': 0.13893774182201898,
#    'b': 0.0002631809807877884,
#    'n': 0.0002631809807877884,
#    'e': 0.0002631809807877884,
#    'y': 0.0002631809807877884,
#    'o': 0.0002631809807877884,
#    'c': 0.0002631809807877884},
#   'veil-type': {'p': 1.0},
#   'veil-color': {'w': 1.0,
#    'n': 0.00026352775825720307,
#    'o': 0.00026352775825720307,
#    'y': 0.00026352775825720307},
#   'ring-number': {'o': 1.0,
#    't': 0.0002635972234425797,
#    'n': 0.0002635972234425797},
#   'ring-type': {'p': 0.7298628209637706,
#    'e': 0.27013717903622936,
#    'l': 0.00026345832967418985,
#    'f': 0.00026345832967418985,
#    'n': 0.00026345832967418985},
#   'spore-print-color': {'k': 0.4861062258177981,
#    'n': 0.49701020049243755,
#    'u': 0.016883573689764335,
#    'h': 0.0002631809807877884,
#    'w': 0.0002631809807877884,
#    'r': 0.0002631809807877884,
#    'o': 0.0002631809807877884,
#    'y': 0.0002631809807877884,
#    'b': 0.0002631809807877884},
#   'population': {'s': 0.2588814632430531,
#    'n': 0.09004572634540978,
#    'a': 0.13506858951811468,
#    'v': 0.2581779810059796,
#    'y': 0.25782623988744285,
#    'c': 0.0002633889376646181},
#   'habitat': {'u': 0.03376714737952867,
#    'g': 0.3939500527611678,
#    'm': 0.09004572634540978,
#    'd': 0.4484699261343651,
#    'p': 0.03376714737952867,
#    'w': 0.00026331958219959624,
#    'l': 0.00026331958219959624}}}

# %%
prior_p = training_data[training_data['class'] == 'p'].shape[0]/training_data.shape[0]

prior_e = training_data[training_data['class'] == 'e'].shape[0]/training_data.shape[0]

# %%
def mock_test(data):
    
    inputs = dict(data)
    
    likelihood_p = 1
    
    likelihood_e = 1
    
    for k,v in inputs.items():
                                
        likelihood_p = likelihood_p * D_of_D['p'][k][v]
    
        likelihood_e = likelihood_e * D_of_D['e'][k][v]
        
    posterior_p = likelihood_p * prior_p
    
    posterior_e = likelihood_e * prior_e
    
    if posterior_p > posterior_e:
        
        return 'p'
    
    else:
        
        return 'e'

# %%
predicted_category = np.array(predicted_category)

# %%
predicted_category
# Out:
# array(['e', 'p', 'e', ..., 'p', 'p', 'e'], dtype='<U1')

# %%
actual_results = np.array(cv_data['class'])

# %%
actual_results
# Out:
# array(['e', 'p', 'e', ..., 'p', 'e', 'e'], dtype=object)

# %%
accuracy = np.count_nonzero(predicted_category == actual_results)/actual_results.shape[0]

# %%
accuracy
# Out:
# 0.5529556650246306
